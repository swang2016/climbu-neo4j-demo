# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
from datetime import timedelta, time, datetime

# %%
#get fight data
fights = pd.read_csv('fight_hist.csv')

#ignore DQs
fights = fights[fights.method != 'DQ']

fights = fights.reset_index(drop = True)

#remove apostrophes from womens divisions
fights['division'] = fights.division.str.replace("'", '')

#eliminate non conventional weight classes
divs = [d for d in fights.division.unique() if d not in ['Open Weight', 'Catch Weight', 'Super Heavyweight']]

fights = fights[fights.division.isin(divs)]

fights['fighter_gender'] = 'Male'
fights.loc[fights.division.str.contains('women', case = False), 'fighter_gender'] = 'Female'
fights['opponent_gender'] = 'Male'
fights.loc[fights.division.str.contains('women', case = False), 'opponent_gender'] = 'Female'

# %%
fights[fights.result == 'W'].head()
# Out:
#                 date                                          fight_url  \
# 0  February 13, 2021  http://ufcstats.com/fight-details/be94e5b7a35c...
# 2  February 13, 2021  http://ufcstats.com/fight-details/25b8c932da5e...
# 4  February 13, 2021  http://ufcstats.com/fight-details/26fbf026beb8...
# 6  February 13, 2021  http://ufcstats.com/fight-details/54e2490959f6...
# 8  February 13, 2021  http://ufcstats.com/fight-details/9201312dd860...
#
#                                            event_url result          fighter  \
# 0  http://ufcstats.com/event-details/3f7c14c7eca7...      W     Kamaru Usman
# 2  http://ufcstats.com/event-details/3f7c14c7eca7...      W     Alexa Grasso
# 4  http://ufcstats.com/event-details/3f7c14c7eca7...      W  Kelvin Gastelum
# 6  http://ufcstats.com/event-details/3f7c14c7eca7...      W      Ricky Simon
# 8  http://ufcstats.com/event-details/3f7c14c7eca7...      W   Julian Marquez
#
#          opponent          division  method  round  time  \
# 0   Gilbert Burns      Welterweight  KO/TKO      3  0:34
# 2   Maycee Barber  Womens Flyweight   U-DEC      3  5:00
# 4    Ian Heinisch      Middleweight   U-DEC      3  5:00
# 6  Brian Kelleher     Featherweight   U-DEC      3  5:00
# 8     Maki Pitolo      Middleweight     SUB      3  4:17
#
#                                          fighter_url  \
# 0  http://ufcstats.com/fighter-details/f1b2aa7853...
# 2  http://ufcstats.com/fighter-details/e8b731feff...
# 4  http://ufcstats.com/fighter-details/8c0580d4ff...
# 6  http://ufcstats.com/fighter-details/5987b2458f...
# 8  http://ufcstats.com/fighter-details/d0e1b42d41...
#
#                                         opponent_url  knockdowns  \
# 0  http://ufcstats.com/fighter-details/23024fdfc9...           2
# 2  http://ufcstats.com/fighter-details/6a740daf1b...           0
# 4  http://ufcstats.com/fighter-details/2e585c701f...           0
# 6  http://ufcstats.com/fighter-details/7be14eaed4...           0
# 8  http://ufcstats.com/fighter-details/c549573c0d...           0
#
#    sub_attempts  pass reversals  takedowns_landed  takedowns_attempts  \
# 0             0     0      2:05                 0                   0
# 2             1     1      5:10                 0                   0
# 4             0     1      6:50                 6                  14
# 6             1     0      8:14                 6                   9
# 8             4     1      1:54                 0                   1
#
#    sig_strikes_landed  sig_strikes_attempts  total_strikes_landed  \
# 0                  83                   136                    93
# 2                  38                    81                    95
# 4                  38                    84                    51
# 6                  45                    98                    72
# 8                  41                   100                    61
#
#    total_strikes_attempts  head_strikes_landed  head_strikes_attempts  \
# 0                     149                   56                    105
# 2                     162                   24                     57
# 4                     115                   20                     62
# 6                     136                   25                     73
# 8                     129                   37                     94
#
#    body_strikes_landed  body_strikes_attempts  leg_strikes_landed  \
# 0                   11                     15                  16
# 2                    9                     14                   5
# 4                   10                     13                   8
# 6                    3                      4                  17
# 8                    3                      4                   1
#
#    leg_strikes_attempts  distance_strikes_landed  distance_strikes_attempts  \
# 0                    16                       54                        100
# 2                    10                       25                         61
# 4                     9                       28                         69
# 6                    21                       29                         74
# 8                     2                       18                         72
#
#    clinch_strikes_landed  clinch_strikes_attempts  ground_strikes_landed  \
# 0                      3                        4                     26
# 2                     13                       20                      0
# 4                      8                       11                      2
# 6                      6                        9                     10
# 8                     15                       16                      8
#
#    ground_strikes_attempts fighter_gender opponent_gender
# 0                       32           Male            Male
# 2                        0         Female          Female
# 4                        4           Male            Male
# 6                       15           Male            Male
# 8                       12           Male            Male

# %%
#connect to Neo4j graph (must have Neo4j instance up and running with default settings, password set to 123)
from py2neo import Graph
graph = Graph(password="123")

# %%
#load data into graph
tx = graph.begin()
for index, row in fights[(fights.result == 'W')].iterrows():
    tx.evaluate('''
       MERGE (a: fighter {name: $fighter, gender: $fighter_gender})
       MERGE (b: fighter {name: $opponent, gender: $opponent_gender})
       MERGE (b)-[r:lose_to {date: $date, division: $division, method: $method}]->(a)
    ''', parameters = {'fighter': row['fighter'], 'opponent': row['opponent'], 'date':row['date'], 
                       'method':row['method'], 'division':row['division'],
                       'fighter_gender':row['fighter_gender'], 'opponent_gender':row['opponent_gender']})
tx.commit()

# %%
#create male graph projection
tx = graph.begin()
cypher = '''
     CALL gds.graph.create.cypher(
    'male_fights',
    "MATCH (f:fighter) WHERE f.gender = 'Male' RETURN id(f) AS id",
    "MATCH (opponent) -[lose_to]-> (fighter) WHERE opponent.gender = 'Male' and fighter.gender = 'Male' RETURN id(opponent) as source, id(fighter) as target"
)'''
tx.run(cypher).data()
# Out:
# [{'nodeQuery': "MATCH (f:fighter) WHERE f.gender = 'Male' RETURN id(f) AS id",
#   'relationshipQuery': "MATCH (opponent) -[lose_to]-> (fighter) WHERE opponent.gender = 'Male' and fighter.gender = 'Male' RETURN id(opponent) as source, id(fighter) as target",
#   'graphName': 'male_fights',
#   'nodeCount': 1872,
#   'relationshipCount': 5234,
#   'createMillis': 47}]

# %%
#create female graph projection
tx = graph.begin()
cypher = '''
CALL gds.graph.create.cypher(
    'female_fights',
    "MATCH (f:fighter) WHERE f.gender = 'Female' RETURN id(f) AS id",
    "MATCH (opponent) -[lose_to]-> (fighter) WHERE opponent.gender = 'Female' and fighter.gender = 'Female' RETURN id(opponent) as source, id(fighter) as target"
)'''
tx.run(cypher).data()
# Out:
# [{'nodeQuery': "MATCH (f:fighter) WHERE f.gender = 'Female' RETURN id(f) AS id",
#   'relationshipQuery': "MATCH (opponent) -[lose_to]-> (fighter) WHERE opponent.gender = 'Female' and fighter.gender = 'Female' RETURN id(opponent) as source, id(fighter) as target",
#   'graphName': 'female_fights',
#   'nodeCount': 184,
#   'relationshipCount': 455,
#   'createMillis': 24}]

# %%
#male connected components
tx = graph.begin()

cypher = '''CALL gds.wcc.write('male_fights', { writeProperty: 'mf_component_id' })
YIELD nodePropertiesWritten, componentCount;
'''

# %time tx.run(cypher).data()
# Out:
# CPU times: user 761 µs, sys: 73 µs, total: 834 µs
# Wall time: 58.8 ms
# [{'nodePropertiesWritten': 1872, 'componentCount': 27}]

# %%
#female connected components
tx = graph.begin()

cypher = '''CALL gds.wcc.write('female_fights', { writeProperty: 'ff_component_id' })
YIELD nodePropertiesWritten, componentCount;
'''

# %time tx.run(cypher).data()
# Out:
# CPU times: user 538 µs, sys: 46 µs, total: 584 µs
# Wall time: 40 ms
# [{'nodePropertiesWritten': 184, 'componentCount': 3}]

# %%
tx = graph.begin()
cypher = '''
CALL gds.pageRank.stream('male_fights')
YIELD
  nodeId,
  score
RETURN gds.util.asNode(nodeId).name AS fighter, score
ORDER BY score DESC
'''
tx.run(cypher).data()
# Out:
# [{'fighter': 'Stipe Miocic', 'score': 11.215403877751669},
#  {'fighter': 'Henry Cejudo', 'score': 11.042557013354962},
#  {'fighter': 'Demetrious Johnson', 'score': 10.533453871184612},
#  {'fighter': 'Dustin Poirier', 'score': 8.78761443226249},
#  {'fighter': 'Junior Dos Santos', 'score': 8.564044779073447},
#  {'fighter': 'Jon Jones', 'score': 8.470969679212429},
#  {'fighter': 'Francis Ngannou', 'score': 8.453018058557062},
#  {'fighter': 'Joseph Benavidez', 'score': 8.229673965024995},
#  {'fighter': 'Max Holloway', 'score': 8.060076443999696},
#  {'fighter': 'Donald Cerrone', 'score': 7.84987305267823},
#  {'fighter': 'Kamaru Usman', 'score': 7.760013837600129},
#  {'fighter': 'Daniel Cormier', 'score': 7.5704781895503395},
#  {'fighter': 'Frankie Edgar', 'score': 7.111835626121319},
#  {'fighter': 'Derrick Lewis', 'score': 6.9421872727747544},
#  {'fighter': 'Aljamain Sterling', 'score': 6.724637681775493},
#  {'fighter': 'Raphael Assuncao', 'score': 6.620791037604283},
#  {'fighter': 'Georges St-Pierre', 'score': 6.572444071492649},
#  {'fighter': 'Israel Adesanya', 'score': 6.414258566196076},
#  {'fighter': 'Dominick Cruz', 'score': 6.399969915192924},
#  {'fighter': 'Rafael Dos Anjos', 'score': 6.23322147671788},
#  {'fighter': 'Khabib Nurmagomedov', 'score': 6.228788375276054},
#  {'fighter': 'Beneil Dariush', 'score': 5.913896925468},
#  {'fighter': 'Demian Maia', 'score': 5.839981812791664},
#  {'fighter': 'Conor McGregor', 'score': 5.788842504154308},
#  {'fighter': 'Anthony Pettis', 'score': 5.770498955756192},
#  {'fighter': 'Matt Hughes', 'score': 5.737766893285153},
#  {'fighter': 'Stephen Thompson', 'score': 5.513131285546116},
#  {'fighter': 'Jussier Formiga', 'score': 5.507784627303772},
#  {'fighter': 'TJ Dillashaw', 'score': 5.090344225416311},
#  {'fighter': 'Robert Whittaker', 'score': 5.017080521427125},
#  {'fighter': 'Alistair Overeem', 'score': 4.954119148998871},
#  {'fighter': 'Charles Oliveira', 'score': 4.950565700751031},
#  {'fighter': 'Marlon Moraes', 'score': 4.945084753632544},
#  {'fighter': 'Deiveson Figueiredo', 'score': 4.717384044917707},
#  {'fighter': 'Stefan Struve', 'score': 4.711426561683766},
#  {'fighter': 'Kevin Lee', 'score': 4.688115880954136},
#  {'fighter': 'Jose Aldo', 'score': 4.626462689304026},
#  {'fighter': 'Nate Diaz', 'score': 4.581090446791496},
#  {'fighter': 'Jorge Masvidal', 'score': 4.539018490418673},
#  {'fighter': 'Tyron Woodley', 'score': 4.512200977493193},
#  {'fighter': 'Cody Garbrandt', 'score': 4.466914100917426},
#  {'fighter': 'Lyoto Machida', 'score': 4.438189584118665},
#  {'fighter': 'Anderson Silva', 'score': 4.377563250035746},
#  {'fighter': 'Curtis Blaydes', 'score': 4.333746354561299},
#  {'fighter': 'Michael Johnson', 'score': 4.240855187578564},
#  {'fighter': 'Andrei Arlovski', 'score': 4.237475078867282},
#  {'fighter': 'BJ Penn', 'score': 4.189773309160956},
#  {'fighter': 'Cory Sandhagen', 'score': 4.170850821502972},
#  {'fighter': 'Edson Barboza', 'score': 4.144358098895463},
#  {'fighter': 'Alexander Volkanovski', 'score': 4.115549567545532},
#  {'fighter': 'Michael Chiesa', 'score': 4.100988983985734},
#  {'fighter': 'Benson Henderson', 'score': 4.082818829981261},
#  {'fighter': 'Tony Ferguson', 'score': 4.08138141327654},
#  {'fighter': 'Glover Teixeira', 'score': 4.035727594047785},
#  {'fighter': 'Chuck Liddell', 'score': 4.020425398716179},
#  {'fighter': 'Fabricio Werdum', 'score': 3.9952256275959366},
#  {'fighter': 'Cain Velasquez', 'score': 3.920998439780669},
#  {'fighter': 'Chris Weidman', 'score': 3.9155329112254553},
#  {'fighter': 'Randy Couture', 'score': 3.866137896565488},
#  {'fighter': 'Yoel Romero', 'score': 3.849331546973553},
#  {'fighter': 'Thiago Santos', 'score': 3.814656375742925},
#  {'fighter': 'Colby Covington', 'score': 3.8117150592850524},
#  {'fighter': 'Rashad Evans', 'score': 3.7092733376426623},
#  {'fighter': 'John Dodson', 'score': 3.6617256380537575},
#  {'fighter': 'Pedro Munhoz', 'score': 3.597778518265113},
#  {'fighter': 'Neil Magny', 'score': 3.5864329460237063},
#  {'fighter': 'Robbie Lawler', 'score': 3.5835875986362233},
#  {'fighter': 'Anthony Johnson', 'score': 3.564963282932877},
#  {'fighter': 'Matt Serra', 'score': 3.549826725797175},
#  {'fighter': 'Jacare Souza', 'score': 3.536477383685997},
#  {'fighter': 'Cub Swanson', 'score': 3.5328509305196345},
#  {'fighter': 'Jan Blachowicz', 'score': 3.486693981312237},
#  {'fighter': 'Derek Brunson', 'score': 3.467194889008533},
#  {'fighter': 'Clay Guida', 'score': 3.4192938044947128},
#  {'fighter': 'Tito Ortiz', 'score': 3.3846400988870307},
#  {'fighter': 'James Krause', 'score': 3.3455948766320933},
#  {'fighter': 'Michael Bisping', 'score': 3.335662370290083},
#  {'fighter': 'Josh Koscheck', 'score': 3.294961880695337},
#  {'fighter': 'Leon Edwards', 'score': 3.285149241951877},
#  {'fighter': 'Kelvin Gastelum', 'score': 3.271451800037176},
#  {'fighter': 'Vitor Belfort', 'score': 3.2550973314995644},
#  {'fighter': 'Johny Hendricks', 'score': 3.1794231784209837},
#  {'fighter': 'Joe Lauzon', 'score': 3.1756518213907845},
#  {'fighter': 'Matt Brown', 'score': 3.162610579438479},
#  {'fighter': 'Rob Font', 'score': 3.1356918512223273},
#  {'fighter': 'Gilbert Burns', 'score': 3.1147939299349665},
#  {'fighter': 'Chan Sung Jung', 'score': 3.097918231594747},
#  {'fighter': 'Diego Sanchez', 'score': 3.0626767437701354},
#  {'fighter': 'Brian Ortega', 'score': 3.0522480973828348},
#  {'fighter': 'Jeremy Stephens', 'score': 3.022204569896712},
#  {'fighter': 'Adriano Martins', 'score': 3.0133645406196594},
#  {'fighter': 'Sergio Pettis', 'score': 3.011098088618746},
#  {'fighter': 'Warlley Alves', 'score': 2.999618048185948},
#  {'fighter': 'Gegard Mousasi', 'score': 2.997496774606406},
#  {'fighter': 'Ryan Bader', 'score': 2.964444967877352},
#  {'fighter': 'Rustam Khabilov', 'score': 2.9518548196720076},
#  {'fighter': 'Michel Prazeres', 'score': 2.9462325584085196},
#  {'fighter': 'Rory MacDonald', 'score': 2.940314622118421},
#  {'fighter': 'Bryan Caraway', 'score': 2.908651557231969},
#  {'fighter': 'Justin Gaethje', 'score': 2.8840166289533946},
#  {'fighter': 'Carlos Condit', 'score': 2.8766206914551735},
#  {'fighter': 'Diego Ferreira', 'score': 2.8667249012738463},
#  {'fighter': 'Al Iaquinta', 'score': 2.8627177151429355},
#  {'fighter': 'Jim Miller', 'score': 2.8601456251539275},
#  {'fighter': 'Mark Hunt', 'score': 2.8332767540062607},
#  {'fighter': 'Uriah Hall', 'score': 2.826772927502316},
#  {'fighter': 'Ricardo Lamas', 'score': 2.825600680199569},
#  {'fighter': 'Alexander Gustafsson', 'score': 2.8238827762019354},
#  {'fighter': 'Anthony Rocco Martin', 'score': 2.822323965758552},
#  {'fighter': 'Mauricio Rua', 'score': 2.8130145123177495},
#  {'fighter': 'Frank Mir', 'score': 2.760584296117303},
#  {'fighter': 'Thiago Alves', 'score': 2.7555331368857874},
#  {'fighter': 'Dong Hyun Kim', 'score': 2.7540773324086327},
#  {'fighter': 'Gray Maynard', 'score': 2.737592889915686},
#  {'fighter': 'Corey Anderson', 'score': 2.707653635798487},
#  {'fighter': 'Vicente Luque', 'score': 2.674947450186301},
#  {'fighter': 'John Lineker', 'score': 2.598096135958621},
#  {'fighter': 'Dan Hooker', 'score': 2.5914223218238472},
#  {'fighter': 'Darren Till', 'score': 2.5883011340825757},
#  {'fighter': 'Leonardo Santos', 'score': 2.5563842704301347},
#  {'fighter': 'Ovince Saint Preux', 'score': 2.542277391898688},
#  {'fighter': 'Travis Browne', 'score': 2.5054742847569282},
#  {'fighter': 'Matt Mitrione', 'score': 2.483024726808071},
#  {'fighter': 'Francisco Trinaldo', 'score': 2.4596745794813617},
#  {'fighter': 'Rich Franklin', 'score': 2.4572531606507253},
#  {'fighter': 'Gleison Tibau', 'score': 2.456842073425651},
#  {'fighter': 'Petr Yan', 'score': 2.454543605310028},
#  {'fighter': 'Santiago Ponzinibbio', 'score': 2.4493015420710433},
#  {'fighter': 'Ben Rothwell', 'score': 2.4380438733380285},
#  {'fighter': 'Nate Marquardt', 'score': 2.4295279026337084},
#  {'fighter': 'Jimmie Rivera', 'score': 2.427236325915874},
#  {'fighter': 'Yair Rodriguez', 'score': 2.419271967938402},
#  {'fighter': 'Brad Tavares', 'score': 2.414345369884285},
#  {'fighter': 'Alexander Volkov', 'score': 2.4057829103549015},
#  {'fighter': 'Yushin Okami', 'score': 2.3833337556396152},
#  {'fighter': 'Darren Elkins', 'score': 2.376486851864865},
#  {'fighter': 'Roy Nelson', 'score': 2.37424203446135},
#  {'fighter': 'Jake Ellenberger', 'score': 2.3415512362669686},
#  {'fighter': 'Dennis Bermudez', 'score': 2.2979058793252993},
#  {'fighter': 'Luke Rockhold', 'score': 2.291986915358574},
#  {'fighter': 'Tim Boetsch', 'score': 2.275011450151214},
#  {'fighter': 'Rick Story', 'score': 2.2548341930320017},
#  {'fighter': 'Dan Henderson', 'score': 2.2265972188484735},
#  {'fighter': 'Phil Davis', 'score': 2.2106424284656896},
#  {'fighter': 'Court McGee', 'score': 2.2060172922647325},
#  {'fighter': 'Calvin Kattar', 'score': 2.1887879896443336},
#  {'fighter': 'Aleksei Oleinik', 'score': 2.1879798505920913},
#  {'fighter': 'Tim Sylvia', 'score': 2.1832309609846554},
#  {'fighter': 'Cezar Ferreira', 'score': 2.1708284417880344},
#  {'fighter': 'Islam Makhachev', 'score': 2.1662959144508935},
#  {'fighter': 'Forrest Griffin', 'score': 2.1633134699746726},
#  {'fighter': 'Shawn Jordan', 'score': 2.1618996849589163},
#  {'fighter': 'Paul Felder', 'score': 2.140538075106451},
#  {'fighter': 'Urijah Faber', 'score': 2.135033356812346},
#  {'fighter': 'Alexander Hernandez', 'score': 2.1271263552480377},
#  {'fighter': 'James Vick', 'score': 2.121440193016315},
#  {'fighter': 'Elizeu Zaleski dos Santos', 'score': 2.1004427981970366},
#  {'fighter': 'Lorenz Larkin', 'score': 2.0918118462006534},
#  {'fighter': 'Drew Dober', 'score': 2.0786453236658415},
#  {'fighter': 'Anthony Smith', 'score': 2.059867754380684},
#  {'fighter': 'Volkan Oezdemir', 'score': 2.037456535286038},
#  {'fighter': 'Eddie Alvarez', 'score': 2.0371383747155045},
#  {'fighter': 'Martin Kampmann', 'score': 2.035235149077199},
#  {'fighter': 'Jon Fitch', 'score': 2.030296288205864},
#  {'fighter': 'Josh Emmett', 'score': 2.0280142762872853},
#  {'fighter': 'Omari Akhmedov', 'score': 2.027236224322405},
#  {'fighter': 'Jairzinho Rozenstruik', 'score': 2.0049406987280234},
#  {'fighter': 'Alex Oliveira', 'score': 2.0001100407986088},
#  {'fighter': 'Bobby Green', 'score': 1.9944023183728856},
#  {'fighter': 'Ross Pearson', 'score': 1.984154904980096},
#  {'fighter': 'Rampage Jackson', 'score': 1.9802149998547975},
#  {'fighter': 'Ryan LaFlare', 'score': 1.9558469872921702},
#  {'fighter': 'Claudio Silva', 'score': 1.944149588490836},
#  {'fighter': 'Chad Mendes', 'score': 1.9398778172863786},
#  {'fighter': 'Zak Cummings', 'score': 1.93107227024675},
#  {'fighter': 'Dustin Ortiz', 'score': 1.9193099710624668},
#  {'fighter': 'Kenny Florian', 'score': 1.9121863900603784},
#  {'fighter': 'Evan Tanner', 'score': 1.9061532810010249},
#  {'fighter': 'Brandon Moreno', 'score': 1.9042938971862897},
#  {'fighter': 'Gunnar Nelson', 'score': 1.8889118257618975},
#  {'fighter': 'Marcin Tybura', 'score': 1.885064330836758},
#  {'fighter': 'Belal Muhammad', 'score': 1.8823719427571635},
#  {'fighter': 'Jack Hermansson', 'score': 1.876046659224084},
#  {'fighter': 'Ricky Simon', 'score': 1.8680192863903355},
#  {'fighter': 'Evan Dunham', 'score': 1.8621742260984322},
#  {'fighter': 'Sam Alvey', 'score': 1.8617875001615176},
#  {'fighter': 'Dominick Reyes', 'score': 1.8589122299919836},
#  {'fighter': 'Chris Lytle', 'score': 1.8539406454423444},
#  {'fighter': 'Nik Lentz', 'score': 1.8484433288715079},
#  {'fighter': 'Renato Moicano', 'score': 1.8418095624478155},
#  {'fighter': 'Mike Pyle', 'score': 1.8391274288267596},
#  {'fighter': 'Marlon Vera', 'score': 1.815890439782879},
#  {'fighter': 'Sergio Moraes', 'score': 1.8150809930084504},
#  {'fighter': 'Thales Leites', 'score': 1.793438091220378},
#  {'fighter': 'Alex Caceres', 'score': 1.7786666060572316},
#  {'fighter': 'Jake Shields', 'score': 1.7704255142482},
#  {'fighter': 'Gabriel Gonzaga', 'score': 1.769316810087184},
#  {'fighter': 'Pedro Rizzo', 'score': 1.7624142555927391},
#  {'fighter': 'Paulo Costa', 'score': 1.7523875563871116},
#  {'fighter': 'Rashid Magomedov', 'score': 1.7440857561497982},
#  {'fighter': 'Cheick Kongo', 'score': 1.7352652290262998},
#  {'fighter': 'Alexandre Pantoja', 'score': 1.7233782945739222},
#  {'fighter': 'Tim Means', 'score': 1.7170477869396565},
#  {'fighter': 'Mark Munoz', 'score': 1.7065522739125298},
#  {'fighter': 'Sean Sherk', 'score': 1.6927210930283767},
#  {'fighter': 'Dennis Siver', 'score': 1.6812133757935952},
#  {'fighter': 'Alex Garcia', 'score': 1.679958421290212},
#  {'fighter': 'Paulo Thiago', 'score': 1.6740638894094446},
#  {'fighter': 'Karo Parisyan', 'score': 1.6696553148289242},
#  {'fighter': 'Ramsey Nijem', 'score': 1.6679167049049286},
#  {'fighter': 'Nikita Krylov', 'score': 1.6596254384372968},
#  {'fighter': 'Misha Cirkunov', 'score': 1.655117160029477},
#  {'fighter': 'Jimi Manuwa', 'score': 1.652902151881062},
#  {'fighter': 'Kevin Holland', 'score': 1.639726834686007},
#  {'fighter': 'Nicolas Dalby', 'score': 1.626314981537871},
#  {'fighter': 'Sean Strickland', 'score': 1.6165777368223644},
#  {'fighter': 'Erik Koch', 'score': 1.6035394082797665},
#  {'fighter': 'Ray Borg', 'score': 1.5993426533725141},
#  {'fighter': 'Melvin Guillard', 'score': 1.596415330238961},
#  {'fighter': 'Bryan Barberena', 'score': 1.5669869966443601},
#  {'fighter': 'Jared Cannonier', 'score': 1.5661108840387896},
#  {'fighter': 'Myles Jury', 'score': 1.565503792767413},
#  {'fighter': 'Keith Jardine', 'score': 1.556620237258903},
#  {'fighter': 'Merab Dvalishvili', 'score': 1.5521170548714962},
#  {'fighter': 'Takeya Mizugaki', 'score': 1.5506219640301422},
#  {'fighter': 'Dan Ige', 'score': 1.5479809635668063},
#  {'fighter': 'Li Jingliang', 'score': 1.5368018670349561},
#  {'fighter': 'Matt Lindland', 'score': 1.5351215866219718},
#  {'fighter': 'Andre Fili', 'score': 1.5287508226712814},
#  {'fighter': 'CB Dollaway', 'score': 1.5286382325975862},
#  {'fighter': 'Jake Matthews', 'score': 1.5227071470493685},
#  {'fighter': 'Josh Barnett', 'score': 1.4990194133686596},
#  {'fighter': 'Ed Herman', 'score': 1.4733395643599578},
#  {'fighter': 'Randy Brown', 'score': 1.468565005902201},
#  {'fighter': 'Cody Stamann', 'score': 1.4622282178432218},
#  {'fighter': 'Tyson Griffin', 'score': 1.460558849103836},
#  {'fighter': 'Dennis Hallman', 'score': 1.454726210582885},
#  {'fighter': 'Desmond Green', 'score': 1.440809903430636},
#  {'fighter': 'Chael Sonnen', 'score': 1.4375518281831317},
#  {'fighter': 'Mike Perry', 'score': 1.437392507772893},
#  {'fighter': 'Alan Jouban', 'score': 1.4286732048829436},
#  {'fighter': 'Chris Leben', 'score': 1.4208438771438525},
#  {'fighter': 'Kajan Johnson', 'score': 1.417717396875378},
#  {'fighter': 'Johnny Walker', 'score': 1.4102238452498563},
#  {'fighter': 'John Howard', 'score': 1.4087300884413712},
#  {'fighter': 'Niko Price', 'score': 1.3929153919860255},
#  {'fighter': 'Joe Stevenson', 'score': 1.3861980967732959},
#  {'fighter': 'Shane Burgos', 'score': 1.3847200151998544},
#  {'fighter': 'Nick Diaz', 'score': 1.3793494461839149},
#  {'fighter': 'Paul Craig', 'score': 1.377594036728351},
#  {'fighter': 'Olivier Aubin-Mercier', 'score': 1.3765656350471542},
#  {'fighter': 'Ciryl Gane', 'score': 1.3749258087947964},
#  {'fighter': 'Elias Theodorou', 'score': 1.3739569742872846},
#  {'fighter': 'Brendan Allen', 'score': 1.3727217132167424},
#  {'fighter': 'Yves Edwards', 'score': 1.3702426959585863},
#  {'fighter': 'Minotauro Nogueira', 'score': 1.3697934669442475},
#  {'fighter': 'Rogerio Nogueira', 'score': 1.3448290131767864},
#  {'fighter': 'Antonio Carlos Junior', 'score': 1.3404933013935079},
#  {'fighter': 'Matt Hamill', 'score': 1.331859511807852},
#  {'fighter': 'Francis Carmont', 'score': 1.3138064425274936},
#  {'fighter': 'Marvin Vettori', 'score': 1.3106238749431214},
#  {'fighter': 'Jared Rosholt', 'score': 1.3033939226195796},
#  {'fighter': 'Mairbek Taisumov', 'score': 1.3024569716915722},
#  {'fighter': 'TJ Grant', 'score': 1.3007147808493758},
#  {'fighter': 'Patrick Cummins', 'score': 1.2999217534761556},
#  {'fighter': 'Zabit Magomedsharipov', 'score': 1.2998899749785775},
#  {'fighter': 'Raoni Barcelos', 'score': 1.2969849242348572},
#  {'fighter': 'Alex Perez', 'score': 1.2966392500544317},
#  {'fighter': 'Gregor Gillespie', 'score': 1.2880441783316203},
#  {'fighter': 'Din Thomas', 'score': 1.2829870674468111},
#  {'fighter': 'Daniel Kelly', 'score': 1.2828316212515347},
#  {'fighter': 'Jens Pulver', 'score': 1.2800575250876143},
#  {'fighter': 'Vinc Pichel', 'score': 1.262138747194331},
#  {'fighter': 'Sam Stout', 'score': 1.2593175487541886},
#  {'fighter': 'Geoff Neal', 'score': 1.2591869583586235},
#  {'fighter': 'John Makdessi', 'score': 1.2510125416039954},
#  {'fighter': 'Jorge Rivera', 'score': 1.2405357596173416},
#  {'fighter': 'Renan Barao', 'score': 1.2305623619278772},
#  {'fighter': 'Marcus Davis', 'score': 1.2277445082669147},
#  {'fighter': 'Brian Ebersole', 'score': 1.225452597916592},
#  {'fighter': 'Ben Saunders', 'score': 1.2218369014633939},
#  {'fighter': 'Frankie Saenz', 'score': 1.2189506764581888},
#  {'fighter': 'Michael Graves', 'score': 1.2183242095168676},
#  {'fighter': 'David Branch', 'score': 1.2101764543433093},
#  {'fighter': 'Brock Lesnar', 'score': 1.2096857598808128},
#  {'fighter': 'Gerald Meerschaert', 'score': 1.1938911921155524},
#  {'fighter': 'Rousimar Palhares', 'score': 1.1908050992205974},
#  {'fighter': 'Matt Wiman', 'score': 1.1816203381607924},
#  {'fighter': 'Ricco Rodriguez', 'score': 1.1791603907768153},
#  {'fighter': 'Jeremy Horn', 'score': 1.1785991925571577},
#  {'fighter': 'Pat Miletich', 'score': 1.175539892652887},
#  {'fighter': 'Antonio Silva', 'score': 1.1664183309781948},
#  {'fighter': 'Seth Baczynski', 'score': 1.1651832342384751},
#  {'fighter': 'Makwan Amirkhani', 'score': 1.1639527758691652},
#  {'fighter': 'Trevin Giles', 'score': 1.1618799747637236},
#  {'fighter': 'Louis Smolka', 'score': 1.159884930423141},
#  {'fighter': 'Spencer Fisher', 'score': 1.1551782590118815},
#  {'fighter': 'Costas Philippou', 'score': 1.1520795977965461},
#  {'fighter': 'George Sotiropoulos', 'score': 1.1514985699197493},
#  {'fighter': 'Rafael Natal', 'score': 1.148354879843464},
#  {'fighter': 'Muslim Salikhov', 'score': 1.147043931367807},
#  {'fighter': 'Ricardo Almeida', 'score': 1.143768334403285},
#  {'fighter': 'Wanderlei Silva', 'score': 1.1435057924638383},
#  {'fighter': 'Ramazan Emeev', 'score': 1.141614938668499},
#  {'fighter': 'Mike Pierce', 'score': 1.1415437980249408},
#  {'fighter': 'Brian Kelleher', 'score': 1.139897161566523},
#  {'fighter': 'Mirsad Bektic', 'score': 1.1381511228764793},
#  {'fighter': 'Mike Swick', 'score': 1.134048023147625},
#  {'fighter': 'Danny Castillo', 'score': 1.1299580558115851},
#  {'fighter': 'Danny Henry', 'score': 1.117058849631576},
#  {'fighter': 'John Hathaway', 'score': 1.113194056332577},
#  {'fighter': 'Aaron Simpson', 'score': 1.108740430552462},
#  {'fighter': 'Chris Camozzi', 'score': 1.1072767455948909},
#  {'fighter': 'Peter Sobotta', 'score': 1.1044179970063854},
#  {'fighter': 'Ismail Naurdiev', 'score': 1.1024959775852035},
#  {'fighter': 'Stephan Bonnar', 'score': 1.094542482587167},
#  {'fighter': 'Gian Villante', 'score': 1.0801047322866906},
#  {'fighter': 'Rick Glenn', 'score': 1.0794717424378175},
#  {'fighter': 'Hector Lombard', 'score': 1.0750274346835793},
#  {'fighter': 'Kendall Grove', 'score': 1.074770288819491},
#  {'fighter': 'Chas Skelly', 'score': 1.07113276321179},
#  {'fighter': 'Rani Yahya', 'score': 1.0709899009714723},
#  {'fighter': 'Rich Clementi', 'score': 1.0704777083708905},
#  {'fighter': 'Hakeem Dawodu', 'score': 1.0692547732847746},
#  {'fighter': 'Walt Harris', 'score': 1.064585277477727},
#  {'fighter': 'Stevie Ray', 'score': 1.0543903588216381},
#  {'fighter': 'Ryan Hall', 'score': 1.052602626741282},
#  {'fighter': 'Albert Tumenov', 'score': 1.049961585991696},
#  {'fighter': 'John Moraga', 'score': 1.0495095584868979},
#  {'fighter': 'Wilson Reis', 'score': 1.0477774053404576},
#  {'fighter': 'Brendan Schaub', 'score': 1.047543885570235},
#  {'fighter': 'Patrick Cote', 'score': 1.045825406591757},
#  {'fighter': 'Arnold Allen', 'score': 1.0426559546972387},
#  {'fighter': 'Marcos Rogerio de Lima', 'score': 1.0313406519275303},
#  {'fighter': 'Yancy Medeiros', 'score': 1.0289434374950361},
#  {'fighter': 'Tom Breese', 'score': 1.0266686501738147},
#  {'fighter': 'Thiago Tavares', 'score': 1.0216368554181827},
#  {'fighter': 'Brandon Vera', 'score': 1.0202299872125873},
#  {'fighter': 'Thiago Silva', 'score': 1.0199080959151618},
#  {'fighter': 'Sean Brady', 'score': 1.0071279369760306},
#  {'fighter': 'Chad Laprise', 'score': 1.0047462849187925},
#  {'fighter': 'Vladimir Matyushenko', 'score': 1.0027194288084502},
#  {'fighter': 'Frank Shamrock', 'score': 1.000385751540307},
#  {'fighter': 'Augusto Sakai', 'score': 1.0002003094181418},
#  {'fighter': 'Giga Chikadze', 'score': 0.9979504606181466},
#  {'fighter': 'Dan Hardy', 'score': 0.9972603624453769},
#  {'fighter': 'Cole Miller', 'score': 0.9966136018716496},
#  {'fighter': 'Jimmy Crute', 'score': 0.9910527341067792},
#  {'fighter': 'Diego Brandao', 'score': 0.9909078989781845},
#  {'fighter': 'Jason Knight', 'score': 0.9854609212823562},
#  {'fighter': 'Aleksandar Rakic', 'score': 0.9835514380712994},
#  {'fighter': 'Nordine Taleb', 'score': 0.9829436056294069},
#  {'fighter': 'Erik Perez', 'score': 0.9827324567548203},
#  {'fighter': 'Daniel Pineda', 'score': 0.9771659013495083},
#  {'fighter': 'Shamil Abdurakhimov', 'score': 0.9761456199776148},
#  {'fighter': 'Krzysztof Jotko', 'score': 0.975453764618578},
#  {'fighter': 'Alan Belcher', 'score': 0.9711865467699682},
#  {'fighter': 'Iuri Alcantara', 'score': 0.9669856416345282},
#  {'fighter': 'Magomed Mustafaev', 'score': 0.9660794741448626},
#  {'fighter': 'Charles Rosa', 'score': 0.9655280806298833},
#  {'fighter': 'Nate Quarry', 'score': 0.9642165309836854},
#  {'fighter': 'Josh Neer', 'score': 0.9578881751076552},
#  {'fighter': 'Damir Ismagulov', 'score': 0.9513589608715849},
#  {'fighter': 'David Teymur', 'score': 0.9479886417251693},
#  {'fighter': 'Ilir Latifi', 'score': 0.9479078208938516},
#  {'fighter': 'Tim Johnson', 'score': 0.9470907355018425},
#  {'fighter': 'Kyoji Horiguchi', 'score': 0.9436674684432544},
#  {'fighter': 'Ali Bagautinov', 'score': 0.941740614212904},
#  {'fighter': 'Song Yadong', 'score': 0.9395393834733115},
#  {'fighter': 'Alex Morono', 'score': 0.9344751995438855},
#  {'fighter': 'Matt Schnell', 'score': 0.9322083886465407},
#  {'fighter': 'Bryce Mitchell', 'score': 0.9254332645570684},
#  {'fighter': 'Julio Arce', 'score': 0.924764157854952},
#  {'fighter': 'Casey Kenney', 'score': 0.9216376654338091},
#  {'fighter': 'Carlos Newton', 'score': 0.9208478327404007},
#  {'fighter': 'Tai Tuivasa', 'score': 0.9207885285606607},
#  {'fighter': 'Movsar Evloev', 'score': 0.8916599823842262},
#  {'fighter': 'Daron Cruickshank', 'score': 0.889725302028819},
#  {'fighter': 'Mike Russow', 'score': 0.8889977203269156},
#  {'fighter': 'Eddie Wineland', 'score': 0.8875323987304001},
#  {'fighter': 'Erick Silva', 'score': 0.8812418492918369},
#  {'fighter': 'Mark Kerr', 'score': 0.8767500162124634},
#  {'fighter': 'Scott Holtzman', 'score': 0.8740709234663314},
#  {'fighter': 'Ryan Benoit', 'score': 0.8663246066775175},
#  {'fighter': 'Valmir Lazaro', 'score': 0.8592434695339763},
#  {'fighter': 'Mark Bocek', 'score': 0.8582669528579572},
#  {'fighter': 'Matthew Riddle', 'score': 0.8557813633672597},
#  {'fighter': 'Ian Heinisch', 'score': 0.8535579090355895},
#  {'fighter': 'Sean Pierson', 'score': 0.8432505509463226},
#  {'fighter': 'Daniel Omielanczuk', 'score': 0.8347912225173787},
#  {'fighter': 'Grant Dawson', 'score': 0.8310248320816755},
#  {'fighter': 'Ricardo Ramos', 'score': 0.8292320106095018},
#  {'fighter': 'Renato Sobral', 'score': 0.8246279536117072},
#  {'fighter': 'Keita Nakamura', 'score': 0.8233239215627689},
#  {'fighter': 'Kevin Randleman', 'score': 0.8184352704760383},
#  {'fighter': 'Brett Johns', 'score': 0.8126773614578268},
#  {'fighter': 'Amir Sadollah', 'score': 0.811447149898231},
#  {'fighter': 'Arman Tsarukyan', 'score': 0.8114351674230419},
#  {'fighter': 'Duane Ludwig', 'score': 0.8109067076195058},
#  {'fighter': 'Roan Carneiro', 'score': 0.8083139092705096},
#  {'fighter': 'Nathaniel Wood', 'score': 0.8049504774369779},
#  {'fighter': 'Mickey Gall', 'score': 0.7982620607705032},
#  {'fighter': 'Alejandro Perez', 'score': 0.7978772563505572},
#  {'fighter': 'Kevin Burns', 'score': 0.7914732750039546},
#  {'fighter': 'Davi Ramos', 'score': 0.7907488874407136},
#  {'fighter': 'Jacob Volkmann', 'score': 0.7890071395246195},
#  {'fighter': 'Khalil Rountree Jr.', 'score': 0.7885311822677294},
#  {'fighter': 'Josh Thomson', 'score': 0.7840348146208274},
#  {'fighter': 'Nick Hein', 'score': 0.7828488032741007},
#  {'fighter': 'Andre Ewell', 'score': 0.7806901267009381},
#  {'fighter': 'Tristan Connelly', 'score': 0.778857957701257},
#  {'fighter': 'Drakkar Klose', 'score': 0.7714715238431384},
#  {'fighter': 'Fabiano Iha', 'score': 0.7704805395308086},
#  {'fighter': 'Joshua Burkman', 'score': 0.7692318487592276},
#  {'fighter': 'Gabriel Benitez', 'score': 0.7631631315254709},
#  {'fighter': 'Dhiego Lima', 'score': 0.7622380978224099},
#  {'fighter': 'Jordan Mein', 'score': 0.7620351421344822},
#  {'fighter': 'Nasrat Haqparast', 'score': 0.7601689488241389},
#  {'fighter': 'Godofredo Pepey', 'score': 0.7593888906114444},
#  {'fighter': 'Felipe Arantes', 'score': 0.7591938015837513},
#  {'fighter': 'Alan Patrick', 'score': 0.7582407376030461},
#  {'fighter': 'Chris Cariaso', 'score': 0.7581141352926349},
#  {'fighter': 'Andrew Holbrook', 'score': 0.7561403368774338},
#  {'fighter': 'Jamie Varner', 'score': 0.7547100349198446},
#  {'fighter': 'Daniel Rodriguez', 'score': 0.7527702397259418},
#  {'fighter': 'Magomed Ankalaev', 'score': 0.7508600399589339},
#  {'fighter': 'Kyle Noke', 'score': 0.7497081628782325},
#  {'fighter': 'Kurt Pellegrino', 'score': 0.7469162967427111},
#  {'fighter': 'Drew Fickett', 'score': 0.7467030961328418},
#  {'fighter': 'Enrique Barzola', 'score': 0.745265522154659},
#  {'fighter': 'Jingliang Li', 'score': 0.744362540129805},
#  {'fighter': 'Sean Spencer', 'score': 0.7439695180655689},
#  {'fighter': 'Paul Kelly', 'score': 0.7426110350435922},
#  {'fighter': 'Sodiq Yusuff', 'score': 0.7421555464403355},
#  {'fighter': 'Brad Riddell', 'score': 0.7415327380644159},
#  {'fighter': 'Devin Clark', 'score': 0.7408591492479901},
#  {'fighter': 'Michel Pereira', 'score': 0.7401859803066374},
#  {'fighter': 'Kyung Ho Kang', 'score': 0.7399186540917074},
#  {'fighter': 'Thiago Moises', 'score': 0.7398318426567132},
#  {'fighter': 'Marco Beltran', 'score': 0.7380002656929718},
#  {'fighter': 'Jonathan Martinez', 'score': 0.737719438898421},
#  {'fighter': 'Shane Carwin', 'score': 0.7375262748092097},
#  {'fighter': 'Efrain Escudero', 'score': 0.7371235642985994},
#  {'fighter': 'Ivan Salaverry', 'score': 0.7353920710636883},
#  {'fighter': 'Edmen Shahbazyan', 'score': 0.7346122118702625},
#  {'fighter': 'Eric Spicely', 'score': 0.7338007684797051},
#  {'fighter': 'Joaquim Silva', 'score': 0.7315865811311596},
#  {'fighter': 'Tim Kennedy', 'score': 0.7313976899982663},
#  {'fighter': 'Said Nurmagomedov', 'score': 0.731197989289649},
#  {'fighter': 'Gavin Tucker', 'score': 0.7261694518634614},
#  {'fighter': 'Michael McDonald', 'score': 0.7255407437536633},
#  {'fighter': 'Jason MacDonald', 'score': 0.7228136287412783},
#  {'fighter': 'Tim Elliott', 'score': 0.721868343136157},
#  {'fighter': 'Mitch Clarke', 'score': 0.717163192379303},
#  {'fighter': 'Ruslan Magomedov', 'score': 0.7163088231114672},
#  {'fighter': 'Alessio Di Chirico', 'score': 0.7137165668333184},
#  {'fighter': 'Murilo Bustamante', 'score': 0.713165322174609},
#  {'fighter': 'Rafael Fiziev', 'score': 0.707741629355951},
#  {'fighter': 'Shonie Carter', 'score': 0.7073499759542756},
#  {'fighter': 'Charlie Brenneman', 'score': 0.7054764602471664},
#  {'fighter': 'Askar Askarov', 'score': 0.705243852379499},
#  {'fighter': 'Blagoy Ivanov', 'score': 0.704278109560255},
#  {'fighter': 'Zak Ottow', 'score': 0.7024838396551785},
#  {'fighter': 'Caol Uno', 'score': 0.702031253424502},
#  {'fighter': 'Tamdan McCrory', 'score': 0.7012643174712139},
#  {'fighter': 'Louis Gaudinot', 'score': 0.7003998156054876},
#  {'fighter': 'Serghei Spivac', 'score': 0.699163846031297},
#  {'fighter': 'Hermes Franca', 'score': 0.6984641788134469},
#  {'fighter': 'Alessio Sakara', 'score': 0.697771867386109},
#  {'fighter': 'Krzysztof Soszynski', 'score': 0.6965550800317941},
#  {'fighter': 'Justin Willis', 'score': 0.6964741655043325},
#  {'fighter': 'Hacran Dias', 'score': 0.6932990980087199},
#  {'fighter': 'Maximo Blanco', 'score': 0.6900518035694402},
#  {'fighter': 'Douglas Silva de Andrade', 'score': 0.6881984155410464},
#  {'fighter': 'Alexander Yakovlev', 'score': 0.6857208969944623},
#  {'fighter': 'Chance Rencountre', 'score': 0.6813165669853335},
#  {'fighter': 'Pete Spratt', 'score': 0.6787678736378439},
#  {'fighter': 'Ottman Azaitar', 'score': 0.6786709901858555},
#  {'fighter': 'Tom Lawlor', 'score': 0.678325203406166},
#  {'fighter': 'Soa Palelei', 'score': 0.6721327233251941},
#  {'fighter': 'Ildemar Alcantara', 'score': 0.6706172397476622},
#  {'fighter': 'Ryan Spann', 'score': 0.6690760151366706},
#  {'fighter': 'Kevin Aguilar', 'score': 0.6666117059095993},
#  {'fighter': 'Roger Huerta', 'score': 0.6653530515447416},
#  {'fighter': 'David Loiseau', 'score': 0.6599967722067958},
#  {'fighter': 'Joe Riggs', 'score': 0.6581394185122917},
#  {'fighter': 'Jason Lambert', 'score': 0.6580064058580319},
#  {'fighter': 'Paul Sass', 'score': 0.6575634175511367},
#  {'fighter': 'Tyson Pedro', 'score': 0.655211430309282},
#  {'fighter': 'Kenny Robertson', 'score': 0.6537258902259053},
#  {'fighter': 'Lyman Good', 'score': 0.6523390744361678},
#  {'fighter': 'Aleksei Kunchenko', 'score': 0.6516897822730241},
#  {'fighter': 'Lerone Murphy', 'score': 0.6485453708446585},
#  {'fighter': 'Cung Le', 'score': 0.6480609497750265},
#  {'fighter': 'Mac Danzig', 'score': 0.6471039390220541},
#  {'fighter': 'Sage Northcutt', 'score': 0.6449409084308173},
#  {'fighter': 'Nico Musoke', 'score': 0.6421086460701193},
#  {'fighter': 'Sheymon Moraes', 'score': 0.6396146736457012},
#  {'fighter': 'David Terrell', 'score': 0.6391596396759267},
#  {'fighter': 'Eryk Anders', 'score': 0.62899961462972},
#  {'fighter': 'Mirko Cro Cop', 'score': 0.6274624848309031},
#  {'fighter': "Jake O'Brien", 'score': 0.6259001256970804},
#  {'fighter': 'Luis Pena', 'score': 0.6245126025728667},
#  {'fighter': 'Andre Soukhamthath', 'score': 0.6195753598120066},
#  {'fighter': 'Antoni Hardonk', 'score': 0.6192384227506409},
#  {'fighter': 'Terry Etim', 'score': 0.6161820665470936},
#  {'fighter': 'Tae Hyun Bang', 'score': 0.6147331943386235},
#  {'fighter': 'Piotr Hallmann', 'score': 0.6142330135837255},
#  {'fighter': 'Abel Trujillo', 'score': 0.6141982185217785},
#  {'fighter': 'Zubaira Tukhugov', 'score': 0.6121149750881386},
#  {'fighter': 'Wilson Gouveia', 'score': 0.6101167245826218},
#  {'fighter': 'Jeff Monson', 'score': 0.6054800384485021},
#  {'fighter': 'Damir Hadzovic', 'score': 0.6019875728990881},
#  {'fighter': 'Miguel Baeza', 'score': 0.6010874903091462},
#  {'fighter': 'Manny Bermudez', 'score': 0.5990043373058143},
#  {'fighter': 'Justin Scoggins', 'score': 0.5972257927554894},
#  {'fighter': 'Maiquel Falcao', 'score': 0.5969435808598063},
#  {'fighter': 'Jerry Bohlander', 'score': 0.5960906289517879},
#  {'fighter': 'Chris Wade', 'score': 0.5951946365974435},
#  {'fighter': 'Abdul Razak Alhassan', 'score': 0.5942581525916466},
#  {'fighter': 'Marcus Brimage', 'score': 0.5933179550891509},
#  {'fighter': 'Chris Daukaus', 'score': 0.5905921941623092},
#  {'fighter': 'Fabio Maldonado', 'score': 0.5892873661259727},
#  {'fighter': 'Cathal Pendred', 'score': 0.5872808614512907},
#  {'fighter': 'Rony Jason', 'score': 0.586988856069729},
#  {'fighter': 'Nick Ring', 'score': 0.5864816527362565},
#  {'fighter': 'Max Griffin', 'score': 0.5851535862719176},
#  {'fighter': 'Falaniko Vitale', 'score': 0.5846940148607245},
#  {'fighter': 'Tomasz Drwal', 'score': 0.5838493313436631},
#  {'fighter': 'Jiri Prochazka', 'score': 0.5823873598419597},
#  {'fighter': 'Jack Marshman', 'score': 0.5809538561943556},
#  {'fighter': 'Brian Foster', 'score': 0.5805414984526579},
#  {'fighter': 'Jose Quinonez', 'score': 0.5799839889976285},
#  {'fighter': 'Eugene Jackson', 'score': 0.5771249979734421},
#  {'fighter': 'George Roop', 'score': 0.5755967144388706},
#  {'fighter': 'Igor Pokrajac', 'score': 0.5721993121931518},
#  {'fighter': 'Dan Miller', 'score': 0.5714765339245788},
#  {'fighter': 'Jake Collier', 'score': 0.570286886824215},
#  {'fighter': 'Gary Goodridge', 'score': 0.5701124995946885},
#  {'fighter': 'Dustin Hazelett', 'score': 0.5692138732339173},
#  {'fighter': 'Dean Lister', 'score': 0.5689390936324344},
#  {'fighter': 'Alberto Mina', 'score': 0.5678173436223005},
#  {'fighter': 'Pat Barry', 'score': 0.5676064111960499},
#  {'fighter': 'Montel Jackson', 'score': 0.5669132883653217},
#  {'fighter': 'Matheus Nicolau', 'score': 0.5668042780471297},
#  {'fighter': 'Davey Grant', 'score': 0.5664689386008829},
#  {'fighter': 'Ning Guangyou', 'score': 0.5648531368933618},
#  {'fighter': 'Curtis Millender', 'score': 0.5648458605312043},
#  {'fighter': 'Takanori Gomi', 'score': 0.5642497800719868},
#  {'fighter': 'Karl Roberson', 'score': 0.563454247832851},
#  {'fighter': 'Siyar Bahadurzada', 'score': 0.562615860486403},
#  {'fighter': 'Andrew Sanchez', 'score': 0.560482087001674},
#  {'fighter': 'Hector Sandoval', 'score': 0.5577521806033476},
#  {'fighter': 'James Head', 'score': 0.5573331571416931},
#  {'fighter': 'Reza Madadi', 'score': 0.5542302936140915},
#  {'fighter': 'Luke Sanders', 'score': 0.5521401849924584},
#  {'fighter': 'Khama Worthy', 'score': 0.551497237010699},
#  {'fighter': 'Brock Larson', 'score': 0.5508797170245087},
#  {'fighter': 'Chico Camus', 'score': 0.5502750935673247},
#  {'fighter': 'Paul Taylor', 'score': 0.5477871852501266},
#  {'fighter': 'Caio Magalhaes', 'score': 0.5448783354292572},
#  {'fighter': 'Ian Freeman', 'score': 0.5445287825423292},
#  {'fighter': 'Frank Trigg', 'score': 0.5435236319783144},
#  {'fighter': 'Tim Credeur', 'score': 0.5429716603194719},
#  {'fighter': 'Ronny Markes', 'score': 0.5429253099362543},
#  {'fighter': 'Anthony Perosh', 'score': 0.5406127454336457},
#  {'fighter': 'Clint Hester', 'score': 0.5393896378198405},
#  {'fighter': 'Guy Mezger', 'score': 0.5387888184632176},
#  {'fighter': 'Darren Stewart', 'score': 0.5386088494822616},
#  {'fighter': 'Tatsuya Kawajiri', 'score': 0.5381898640742294},
#  {'fighter': 'Anthony Hernandez', 'score': 0.5378490549064511},
#  {'fighter': 'James Te Huna', 'score': 0.5374525726857426},
#  {'fighter': 'Mario Bautista', 'score': 0.5368861705209967},
#  {'fighter': 'Polo Reyes', 'score': 0.5366452029205901},
#  {'fighter': 'Joe Duffy', 'score': 0.5360202974115965},
#  {'fighter': 'Luiz Cane', 'score': 0.5346501885040199},
#  {'fighter': 'Paul Daley', 'score': 0.5345922158330721},
#  {'fighter': 'Vitor Miranda', 'score': 0.5327993938859434},
#  {'fighter': 'Daniel Roberts', 'score': 0.5322693233745668},
#  {'fighter': 'Magnus Cedenblad', 'score': 0.5321673476326167},
#  {'fighter': 'Eddie Sanchez', 'score': 0.5314417009605676},
#  {'fighter': 'Rich Attonito', 'score': 0.5298917808126248},
#  {'fighter': 'Roosevelt Roberts', 'score': 0.529494198661996},
#  {'fighter': 'Gerald Harris', 'score': 0.5261362177392586},
#  {'fighter': 'Yves Jabouin', 'score': 0.523044585454045},
#  {'fighter': 'Sam Sicilia', 'score': 0.5222957713122014},
#  {'fighter': 'Manvel Gamburyan', 'score': 0.5200313284287403},
#  {'fighter': 'Nick Osipczak', 'score': 0.5199616672782211},
#  {'fighter': 'Trevor Smith', 'score': 0.5195699081978092},
#  {'fighter': 'Marc Diakiese', 'score': 0.5195319638878574},
#  {'fighter': 'Khaos Williams', 'score': 0.51669962174783},
#  {'fighter': 'Michael Chandler', 'score': 0.5162740347383079},
#  {'fighter': 'Andrew Craig', 'score': 0.5161258404637922},
#  {'fighter': 'Brian Stann', 'score': 0.5141991812969081},
#  {'fighter': 'Gan McGee', 'score': 0.512767701933626},
#  {'fighter': 'DaMarques Johnson', 'score': 0.5121796822804756},
#  {'fighter': 'Danny Roberts', 'score': 0.5118384938586132},
#  {'fighter': 'Ilia Topuria', 'score': 0.5099807074904675},
#  {'fighter': 'TJ Waldburger', 'score': 0.5080895369233078},
#  {'fighter': 'Joaquin Buckley', 'score': 0.5073323111544596},
#  {'fighter': 'Jordan Johnson', 'score': 0.506031430697476},
#  {'fighter': 'Luigi Fioravanti', 'score': 0.5058725427538888},
#  {'fighter': 'Laverne Clark', 'score': 0.5049771202369782},
#  {'fighter': "Sean O'Malley", 'score': 0.5045434804276738},
#  {'fighter': 'Chris Gruetzemacher', 'score': 0.5020219703292241},
#  {'fighter': 'Norman Parke', 'score': 0.501192689304844},
#  {'fighter': 'Maurice Greene', 'score': 0.5002244890150904},
#  {'fighter': 'Brad Pickett', 'score': 0.4998493356605648},
#  {'fighter': 'Francisco Rivera', 'score': 0.4986316190894286},
#  {'fighter': 'Ulka Sasaki', 'score': 0.49815934139260204},
#  {'fighter': 'Greg Hardy', 'score': 0.49509989704165497},
#  {'fighter': 'Andre Roberts', 'score': 0.494250001013279},
#  {'fighter': 'Jonathan Brookins', 'score': 0.4932529629810311},
#  {'fighter': 'Thomas Almeida', 'score': 0.4930737760154444},
#  {'fighter': 'Ben Nguyen', 'score': 0.493042405525921},
#  {'fighter': 'KJ Noons', 'score': 0.49166762707463924},
#  {'fighter': 'Herbert Burns', 'score': 0.49132767391274684},
#  {'fighter': 'Marcio Cruz', 'score': 0.4903412835556083},
#  {'fighter': 'Lando Vannata', 'score': 0.4903328473155852},
#  {'fighter': 'Ben Askren', 'score': 0.48751786603825165},
#  {'fighter': 'Bas Rutten', 'score': 0.4850164390620194},
#  {'fighter': 'Dwight Grant', 'score': 0.48257240873243745},
#  {'fighter': 'Ion Cutelaba', 'score': 0.4813909945964951},
#  {'fighter': 'Brandon Davis', 'score': 0.4799796078513453},
#  {'fighter': 'Matt Frevola', 'score': 0.47970993730486955},
#  {'fighter': 'Steven Siler', 'score': 0.47904625308619864},
#  {'fighter': 'Jess Liaudin', 'score': 0.47761574176256544},
#  {'fighter': 'Alonzo Menifield', 'score': 0.4744642293539073},
#  {'fighter': 'Jon Tuck', 'score': 0.4741764213864371},
#  {'fighter': 'Josh Samman', 'score': 0.47351505835831637},
#  {'fighter': 'Marcin Held', 'score': 0.4727917556665489},
#  {'fighter': 'Adam Wieczorek', 'score': 0.471422984826495},
#  {'fighter': 'Roland Delorme', 'score': 0.4683245487045497},
#  {'fighter': 'Joe Soto', 'score': 0.4681438674875609},
#  {'fighter': 'Hyun Gyu Lim', 'score': 0.467687513679266},
#  {'fighter': 'Johnny Bedford', 'score': 0.4658035352884327},
#  {'fighter': 'Claude Patrick', 'score': 0.4620471292189905},
#  {'fighter': 'Ivan Menjivar', 'score': 0.45737594860838726},
#  {'fighter': 'Terry Martin', 'score': 0.4566360781871481},
#  {'fighter': 'Youssef Zalal', 'score': 0.456000005826354},
#  {'fighter': 'Michael Trizano', 'score': 0.45439481864887044},
#  {'fighter': 'Makhmud Muradov', 'score': 0.45348223031551244},
#  {'fighter': 'Bojan Velickovic', 'score': 0.4531190720990709},
#  {'fighter': 'Leandro Silva', 'score': 0.45248801412089956},
#  {'fighter': 'Eric Schafer', 'score': 0.4516102553825476},
#  {'fighter': 'Luke Barnatt', 'score': 0.45084468295244734},
#  {'fighter': 'Pablo Garza', 'score': 0.45041068614809776},
#  {'fighter': 'Yoshiyuki Yoshida', 'score': 0.4496250055730343},
#  {'fighter': 'Kevin Jackson', 'score': 0.4496250055730343},
#  {'fighter': 'Sean McCorkle', 'score': 0.44906306738266727},
#  {'fighter': 'Jimy Hettes', 'score': 0.44842547783082415},
#  {'fighter': 'Kyle Kingsbury', 'score': 0.4484029771316272},
#  {'fighter': 'Guido Cannetti', 'score': 0.44747834542445153},
#  {'fighter': 'Maurice Smith', 'score': 0.44549843197369215},
#  {'fighter': 'Jonathan Goulet', 'score': 0.44496411211398895},
#  {'fighter': 'Kyle Bochniak', 'score': 0.44269100450655957},
#  {'fighter': 'Johnny Case', 'score': 0.4425549120043797},
#  {'fighter': 'Markus Perez', 'score': 0.4423343942436076},
#  {'fighter': 'Joey Beltran', 'score': 0.44193280108647737},
#  {'fighter': 'Robert Peralta', 'score': 0.44151171621069807},
#  {'fighter': 'Antonio Braga Neto', 'score': 0.4413904834655114},
#  {'fighter': 'Taylor Lapilus', 'score': 0.440637078319287},
#  {'fighter': 'Kai Kara-France', 'score': 0.43998230881406925},
#  {'fighter': 'Jason Brilz', 'score': 0.43863560650206634},
#  {'fighter': 'Tony DeSouza', 'score': 0.43798740393231134},
#  {'fighter': 'Damian Stasiak', 'score': 0.43794584921306523},
#  {'fighter': 'Francimar Barroso', 'score': 0.43783664328020677},
#  {'fighter': 'Tom Watson', 'score': 0.4376311499644089},
#  {'fighter': 'Heath Herring', 'score': 0.43750512446276846},
#  {'fighter': 'Andre Muniz', 'score': 0.43667417404521985},
#  {'fighter': 'Takashi Sato', 'score': 0.43541403266863205},
#  {'fighter': 'Jared Gordon', 'score': 0.43321524943312395},
#  {'fighter': 'Justin McCully', 'score': 0.43205359385174225},
#  {'fighter': 'Jonathan Pearce', 'score': 0.43193437717854977},
#  {'fighter': 'Anthony Njokuani', 'score': 0.431658044465439},
#  {'fighter': 'Diego Rivas', 'score': 0.43085945147322485},
#  {'fighter': 'Mitch Gagnon', 'score': 0.43084909996438225},
#  {'fighter': 'James Irvin', 'score': 0.4306336639026994},
#  {'fighter': 'Tarec Saffiedine', 'score': 0.4299900165642612},
#  {'fighter': 'Jamahal Hill', 'score': 0.4298631307101459},
#  {'fighter': 'Cyrille Diabate', 'score': 0.4274332452964699},
#  {'fighter': 'Chris Holdsworth', 'score': 0.42737304117299574},
#  {'fighter': 'Yoshihiro Akiyama', 'score': 0.42537154951569384},
#  {'fighter': 'Joel Alvarez', 'score': 0.42446590247564026},
#  {'fighter': 'Lance Benoist', 'score': 0.42433666664492203},
#  {'fighter': 'Heili Alateng', 'score': 0.42416616510890887},
#  {'fighter': 'Houston Alexander', 'score': 0.4235325041776378},
#  {'fighter': 'Rodrigo Damm', 'score': 0.42337166695979245},
#  {'fighter': 'Justin Ledet', 'score': 0.42095464275198524},
#  {'fighter': 'Lucas Martins', 'score': 0.420732349204991},
#  {'fighter': 'Mike Grundy', 'score': 0.4204195320606232},
#  {'fighter': 'Khamzat Chimaev', 'score': 0.4189799821760972},
#  {'fighter': 'Russell Doane', 'score': 0.41823415642793416},
#  {'fighter': 'Martin Bravo', 'score': 0.4178418783798861},
#  {'fighter': 'Junior Albini', 'score': 0.4175076399522367},
#  {'fighter': 'Eliot Marshall', 'score': 0.4154322129764068},
#  {'fighter': 'Drew McFedries', 'score': 0.41464162305310304},
#  {'fighter': 'Jeremy Kennedy', 'score': 0.41369285556938845},
#  {'fighter': 'Junior Assuncao', 'score': 0.412597325531533},
#  {'fighter': 'Brian Bowles', 'score': 0.41168743491580256},
#  {'fighter': 'Jon Madsen', 'score': 0.4104241785384261},
#  {'fighter': 'SeungWoo Choi', 'score': 0.4075500058010221},
#  {'fighter': 'Cody McKenzie', 'score': 0.40689939179072787},
#  {'fighter': 'George Sullivan', 'score': 0.40641062448339654},
#  {'fighter': 'Antonio Carvalho', 'score': 0.40591353054758206},
#  {'fighter': 'Che Mills', 'score': 0.4057613161878181},
#  {'fighter': 'Laureano Staropoli', 'score': 0.40505158895102783},
#  {'fighter': 'Brandon Royval', 'score': 0.40502625033477674},
#  {'fighter': 'Alex Hunter', 'score': 0.40500001013278963},
#  {'fighter': 'Sam Hoger', 'score': 0.40500001013278963},
#  {'fighter': 'Mike van Arsdale', 'score': 0.40500001013278963},
#  {'fighter': 'Tony Fryklund', 'score': 0.40500001013278963},
#  {'fighter': 'Ron Waterman', 'score': 0.40500001013278963},
#  {'fighter': 'Shinsho Anzai', 'score': 0.40483028153817036},
#  {'fighter': 'Dave Menne', 'score': 0.40457085833095013},
#  {'fighter': 'Hugo Viana', 'score': 0.4037190422555796},
#  {'fighter': 'Igor Araujo', 'score': 0.40356637724326},
#  {'fighter': 'Alex White', 'score': 0.40243002592906135},
#  {'fighter': 'Nate Landwehr', 'score': 0.40208675648027564},
#  {'fighter': 'Joe Proctor', 'score': 0.40162286230624894},
#  {'fighter': 'Dooho Choi', 'score': 0.4010451643409398},
#  {'fighter': 'Pete Williams', 'score': 0.4001650912096465},
#  {'fighter': 'Chris Gutierrez', 'score': 0.3991250432562083},
#  {'fighter': 'Hunter Azure', 'score': 0.39896350141412706},
#  {'fighter': 'Tom Aspinall', 'score': 0.39865367415841324},
#  {'fighter': 'Ryan Janes', 'score': 0.39658461416220236},
#  {'fighter': 'Jordan Rinaldi', 'score': 0.3958741251757601},
#  {'fighter': 'Scott Jorgensen', 'score': 0.3957403182750568},
#  {'fighter': 'Mark Hominick', 'score': 0.3954662107928016},
#  {'fighter': 'Don Madge', 'score': 0.39543750658631327},
#  {'fighter': 'Aaron Riley', 'score': 0.3952518858044641},
#  {'fighter': 'Carmelo Marrero', 'score': 0.39500512382946906},
#  {'fighter': 'Nick Catone', 'score': 0.3943457452918664},
#  {'fighter': 'Phillip Miller', 'score': 0.3933716088999063},
#  {'fighter': 'James Wilks', 'score': 0.3933408838608557},
#  {'fighter': 'Andrei Semenov', 'score': 0.3927276164380601},
#  {'fighter': 'Shavkat Rakhmonov', 'score': 0.3924966856109677},
#  {'fighter': 'Jason Saggo', 'score': 0.3916297350289824},
#  {'fighter': 'Damon Jackson', 'score': 0.39148374714714007},
#  {'fighter': 'Zhang Lipeng', 'score': 0.39134687765035775},
#  {'fighter': 'Brad Blackburn', 'score': 0.39071423419736684},
#  {'fighter': 'Kevin Souza', 'score': 0.3905351715936377},
#  {'fighter': 'Hatsu Hioki', 'score': 0.389668023212289},
#  {'fighter': 'Alexandr Romanov', 'score': 0.3890436847257661},
#  {'fighter': 'Chris Kelades', 'score': 0.3885008557619586},
#  {'fighter': 'Mike Wilkinson', 'score': 0.3866442679051033},
#  {'fighter': 'Paul Buentello', 'score': 0.3861440338392639},
#  {'fighter': 'Bill Algeo', 'score': 0.3858750030398369},
#  {'fighter': 'Ikuhisa Minowa', 'score': 0.3858750030398369},
#  {'fighter': 'Adlan Amagov', 'score': 0.3854516302526462},
#  {'fighter': 'Justin Salas', 'score': 0.3850313440452738},
#  {'fighter': 'Justin Eilers', 'score': 0.38348889337230513},
#  {'fighter': 'Christos Giagos', 'score': 0.3830517161528407},
#  {'fighter': 'Su Mudaerji', 'score': 0.38274590190776503},
#  {'fighter': 'Elias Silverio', 'score': 0.3822893991164166},
#  {'fighter': 'Punahele Soriano', 'score': 0.38226483267100114},
#  {'fighter': 'Diego Nunes', 'score': 0.38162929195677864},
#  {'fighter': 'Scott Adams', 'score': 0.38117770231910975},
#  {'fighter': 'Miles Johns', 'score': 0.380160542492385},
#  {'fighter': 'Gadzhimurad Antigulov', 'score': 0.37983534829982096},
#  {'fighter': 'Rob Whiteford', 'score': 0.37970010601129617},
#  {'fighter': 'Brandon Thatch', 'score': 0.3791979894507676},
#  {'fighter': 'Frank Camacho', 'score': 0.3786159960058286},
#  {'fighter': 'Ludovit Klein', 'score': 0.378298377910025},
#  {'fighter': 'Sultan Aliev', 'score': 0.3782231599609076},
#  {'fighter': 'Bobby Moffett', 'score': 0.37746968422870847},
#  {'fighter': 'Tom Niinimaki', 'score': 0.3774215627796366},
#  {'fighter': 'Anthony Hamilton', 'score': 0.37653727677825377},
#  {'fighter': 'Patrick Williams', 'score': 0.37596505144392733},
#  {'fighter': 'Jake Hecht', 'score': 0.3751164677800262},
#  {'fighter': 'Bartosz Fabinski', 'score': 0.37457756760995836},
#  {'fighter': 'Mike de la Torre', 'score': 0.37402520842479137},
#  {'fighter': 'Joe Solecki', 'score': 0.3720954809155957},
#  {'fighter': 'Jason High', 'score': 0.3714996608512593},
#  {'fighter': 'Luke Cummo', 'score': 0.37012343909591433},
#  {'fighter': 'Omar Morales', 'score': 0.3673692451433454},
#  {'fighter': 'Viscardi Andrade', 'score': 0.3654027353666607},
#  {'fighter': 'Tsuyoshi Kohsaka', 'score': 0.36479265945891937},
#  {'fighter': 'Thibault Gouti', 'score': 0.3638842125335941},
#  {'fighter': 'Phil Baroni', 'score': 0.3634713047818081},
#  {'fighter': 'Bradley Scott', 'score': 0.36331731084371766},
#  {'fighter': 'Michinori Tanaka', 'score': 0.36221280189238314},
#  {'fighter': 'Neil Seery', 'score': 0.3618473095209993},
#  {'fighter': 'Noad Lahat', 'score': 0.3609151353430207},
#  {'fighter': 'Jalin Turner', 'score': 0.3595649872455397},
#  {'fighter': 'Augusto Mendes', 'score': 0.3567806864273734},
#  {'fighter': 'Bart Palaszewski', 'score': 0.356396733110887},
#  {'fighter': 'Mike Brown', 'score': 0.35597940877237305},
#  {'fighter': 'Roman Dolidze', 'score': 0.3555415510811827},
#  {'fighter': 'Miguel Torres', 'score': 0.3547968823462725},
#  {'fighter': 'William Knight', 'score': 0.35353017521238156},
#  {'fighter': 'Genki Sudo', 'score': 0.3530987828067737},
#  {'fighter': 'Sergei Pavlovich', 'score': 0.35218540230343937},
#  {'fighter': 'Tanner Boser', 'score': 0.3509822741662902},
#  {'fighter': 'Gilbert Melendez', 'score': 0.3498848950257526},
#  {'fighter': 'Rogerio Bontorin', 'score': 0.3486741605505813},
#  {'fighter': 'Paddy Holohan', 'score': 0.3479641102661845},
#  {'fighter': 'Mark Coleman', 'score': 0.3466152420889557},
#  {'fighter': 'Joe Doerksen', 'score': 0.34596156033258024},
#  {'fighter': 'Renato Verissimo', 'score': 0.34554479090948},
#  {'fighter': 'Brad Katona', 'score': 0.34425346351499686},
#  {'fighter': 'Zach Makovsky', 'score': 0.3439299041339836},
#  {'fighter': 'Dongi Yang', 'score': 0.3436693040981482},
#  {'fighter': 'Edwin Figueroa', 'score': 0.34337344966043026},
#  {'fighter': 'Christian Wellisch', 'score': 0.34314453054502114},
#  {'fighter': 'Johnny Eduardo', 'score': 0.3419176171270009},
#  {'fighter': 'David Heath', 'score': 0.34125000759959223},
#  {'fighter': 'Marcus Aurelio', 'score': 0.34125000759959223},
#  {'fighter': 'Waylon Lowe', 'score': 0.34125000759959223},
#  {'fighter': 'Rob Kimmons', 'score': 0.34125000759959223},
#  {'fighter': 'Daniel Sarafian', 'score': 0.34125000759959223},
#  {'fighter': 'Austin Hubbard', 'score': 0.34125000759959223},
#  {'fighter': 'Pascal Krauss', 'score': 0.34125000759959223},
#  {'fighter': 'Kyler Phillips', 'score': 0.34125000759959223},
#  {'fighter': 'Mike Davis', 'score': 0.34125000759959223},
#  {'fighter': 'Mikey Burnett', 'score': 0.34125000759959223},
#  {'fighter': 'Carlos Felipe', 'score': 0.3405699952229043},
#  {'fighter': 'Christian Morecraft', 'score': 0.3398339310544544},
#  {'fighter': 'Kevin Casey', 'score': 0.33981637787655933},
#  {'fighter': 'Rob Emerson', 'score': 0.3392519471059132},
#  {'fighter': 'Fredy Serrano', 'score': 0.33806250272318716},
#  {'fighter': 'Royston Wee', 'score': 0.33806250272318716},
#  {'fighter': 'Dylan Andrews', 'score': 0.33806250272318716},
#  {'fighter': 'Jared Hamman', 'score': 0.3366964440370793},
#  {'fighter': 'Todd Duffee', 'score': 0.33614014469403636},
#  {'fighter': 'Kalib Starnes', 'score': 0.33443665451850396},
#  {'fighter': 'Mike Easton', 'score': 0.3340039111149963},
#  {'fighter': 'Steven Peterson', 'score': 0.3321365020490588},
#  {'fighter': 'Philip De Fries', 'score': 0.33168750405311587},
#  {'fighter': 'Kai Kamaka', 'score': 0.33168750405311587},
#  {'fighter': 'Tra Telligman', 'score': 0.33168750405311587},
#  {'fighter': 'Chase Sherman', 'score': 0.33035937873646615},
#  {'fighter': 'Gasan Umalatov', 'score': 0.3275412444694667},
#  {'fighter': 'Dustin Kimura', 'score': 0.32748970101611125},
#  {'fighter': 'Teruto Ishihara', 'score': 0.3272604249417782},
#  {'fighter': 'Klidson Abreu', 'score': 0.3256125720901764},
#  {'fighter': 'Dong Hyun Ma', 'score': 0.32539055465458666},
#  {'fighter': 'Arjan Bhullar', 'score': 0.32441911760834047},
#  {'fighter': 'Ryan Jimmo', 'score': 0.32392472112615},
#  {'fighter': 'Wesley Correira', 'score': 0.3228333442471922},
#  {'fighter': 'Goran Reljic', 'score': 0.3227431507679283},
#  {'fighter': 'Michal Oleksiejczuk', 'score': 0.32242542649983086},
#  {'fighter': 'Chris Beal', 'score': 0.32023876761031717},
#  {'fighter': 'Juan Espino', 'score': 0.32000000569969417},
#  {'fighter': 'David Abbott', 'score': 0.3200000025331974},
#  {'fighter': 'Jorge Gurgel', 'score': 0.3200000025331974},
#  {'fighter': 'Mike Rodriguez', 'score': 0.31955143456061696},
#  {'fighter': 'Mounir Lazzez', 'score': 0.3181960207846714},
#  {'fighter': 'Nad Narimani', 'score': 0.3181406293064356},
#  {'fighter': 'Leonard Garcia', 'score': 0.3175293103606692},
#  {'fighter': 'Song Kenan', 'score': 0.3170649771127501},
#  {'fighter': 'Claudio Puelles', 'score': 0.3151146736079226},
#  {'fighter': 'Brian Melancon', 'score': 0.3148441205004928},
#  {'fighter': 'Matthew Lopez', 'score': 0.3141772773333286},
#  {'fighter': 'Tiago Trator', 'score': 0.31334890313301006},
#  {'fighter': 'Shane Campbell', 'score': 0.31244694399792944},
#  {'fighter': 'Emil Meek', 'score': 0.3118262276868337},
#  {'fighter': 'Andre Winner', 'score': 0.3110882833367214},
#  {'fighter': 'Mark Madsen', 'score': 0.3104375021532178},
#  {'fighter': 'Eric Shelton', 'score': 0.3087074520182796},
#  {'fighter': 'Ben Earwood', 'score': 0.30731638958532137},
#  {'fighter': 'Rodolfo Vieira', 'score': 0.3062960791245247},
#  {'fighter': 'Akira Corassani', 'score': 0.3060008952742464},
#  {'fighter': 'Rafaello Oliveira', 'score': 0.30459375455975535},
#  {'fighter': 'Buddy Roberts', 'score': 0.304292036388506},
#  {'fighter': 'Justin Edwards', 'score': 0.3040618690334668},
#  {'fighter': 'Mackens Semerzier', 'score': 0.30087344902713087},
#  {'fighter': 'Wang Guan', 'score': 0.30087344902713087},
#  {'fighter': 'Kron Gracie', 'score': 0.30087344902713087},
#  {'fighter': 'Masanori Kanehara', 'score': 0.30087344902713087},
#  {'fighter': 'Lee Murray', 'score': 0.30049336541706007},
#  {'fighter': 'Forrest Petz', 'score': 0.29974833518443555},
#  {'fighter': 'Luke Jumeau', 'score': 0.29960777610694994},
#  {'fighter': 'Shane Roller', 'score': 0.29940035103718404},
#  {'fighter': 'Jarred Brooks', 'score': 0.29865463396417913},
#  {'fighter': 'Greg Soto', 'score': 0.297318927132801},
#  {'fighter': 'Javier Vazquez', 'score': 0.2969588843363454},
#  {'fighter': 'Joshua Sampo', 'score': 0.2966661600425141},
#  {'fighter': 'Vaughan Lee', 'score': 0.2962793052942744},
#  {'fighter': 'Shannon Gugerty', 'score': 0.2952502289074431},
#  {'fighter': 'Damien Brown', 'score': 0.29428852858654875},
#  {'fighter': 'Khalid Murtazaliev', 'score': 0.29419644340378},
#  {'fighter': 'Anthony Birchak', 'score': 0.2932979318353317},
#  {'fighter': 'Elvis Sinosic', 'score': 0.29300631562364293},
#  {'fighter': 'Ebenezer Fontes Braga', 'score': 0.29300631562364293},
#  {'fighter': 'Billy Quarantillo', 'score': 0.29237500037997965},
#  {'fighter': 'Steve Bosse', 'score': 0.2888595473982605},
#  {'fighter': 'John Maguire', 'score': 0.2887167601055809},
#  {'fighter': 'Tom Duquesnoy', 'score': 0.28836376951021525},
#  {'fighter': 'Shamil Gamzatov', 'score': 0.28826178338786135},
#  {'fighter': 'Jason Day', 'score': 0.28751224670959347},
#  {'fighter': 'David Dvorak', 'score': 0.28732020692550586},
#  {'fighter': 'Ryo Chonan', 'score': 0.28726817135247973},
#  {'fighter': 'David Bielkheden', 'score': 0.28525630751501013},
#  {'fighter': 'Julian Marquez', 'score': 0.2846006540639792},
#  {'fighter': 'Marcin Prachnio', 'score': 0.28399719480767094},
#  {'fighter': 'Travis Lutter', 'score': 0.28319421704618436},
#  {'fighter': 'Nam Phan', 'score': 0.2826281052938498},
#  {'fighter': 'Yaotzin Meza', 'score': 0.28187878952376194},
#  {'fighter': 'Cody Gibson', 'score': 0.2817788632353767},
#  {'fighter': 'Kiichi Kunimoto', 'score': 0.28148438259959224},
#  {'fighter': 'Lavar Johnson', 'score': 0.28147305800739564},
#  {'fighter': 'Will Brooks', 'score': 0.2795139123642002},
#  {'fighter': "Sean O'Connell", 'score': 0.2793945264285754},
#  {'fighter': 'Roger Narvaez', 'score': 0.2777091087180452},
#  {'fighter': 'Patrick Walsh', 'score': 0.27750000506639483},
#  {'fighter': 'Luke Zachrich', 'score': 0.27750000506639483},
#  {'fighter': 'Tor Troeng', 'score': 0.27750000506639483},
#  {'fighter': 'An Ying Wang', 'score': 0.27750000506639483},
#  {'fighter': 'Masio Fullen', 'score': 0.27750000506639483},
#  {'fighter': 'Nassourdine Imavov', 'score': 0.27750000506639483},
#  {'fighter': 'Alex Da Silva', 'score': 0.27750000506639483},
#  {'fighter': 'Darrick Minner', 'score': 0.27750000506639483},
#  {'fighter': 'Randy Costa', 'score': 0.27750000506639483},
#  {'fighter': 'Kyle Nelson', 'score': 0.27750000506639483},
#  {'fighter': 'Matthew Semelsberger', 'score': 0.27750000506639483},
#  {'fighter': 'Nate Maness', 'score': 0.27750000506639483},
#  {'fighter': 'Jamall Emmers', 'score': 0.27750000506639483},
#  {'fighter': 'Aaron Rosa', 'score': 0.27750000506639483},
#  {'fighter': 'Chris Cope', 'score': 0.27750000506639483},
#  {'fighter': 'Shamar Bailey', 'score': 0.27750000506639483},
#  {'fighter': 'Rob Broughton', 'score': 0.27750000506639483},
#  {'fighter': 'Ian Loveland', 'score': 0.27750000506639483},
#  {'fighter': 'Curt Warburton', 'score': 0.27750000506639483},
#  {'fighter': 'Kyle Watson', 'score': 0.27750000506639483},
#  {'fighter': 'Julian Erosa', 'score': 0.27750000506639483},
#  {'fighter': 'Joe Slick', 'score': 0.27750000506639483},
#  {'fighter': 'Paul Jones', 'score': 0.27750000506639483},
#  {'fighter': 'Marcelo Mello', 'score': 0.27750000506639483},
#  {'fighter': 'Sione Latu', 'score': 0.27750000506639483},
#  {'fighter': 'Kazushi Sakuraba', 'score': 0.27750000506639483},
#  {'fighter': 'Dwayne Cason', 'score': 0.27750000506639483},
#  {'fighter': 'Dave Beneteau', 'score': 0.27750000506639483},
#  {'fighter': 'Dan Bobish', 'score': 0.27750000506639483},
#  {'fighter': 'Joe Moreira', 'score': 0.27750000506639483},
#  {'fighter': 'Steven Graham', 'score': 0.27750000506639483},
#  {'fighter': 'Jack Nilson', 'score': 0.27750000506639483},
#  {'fighter': 'Scott Ferrozzo', 'score': 0.27750000506639483},
#  {'fighter': 'Yoshiki Takahashi', 'score': 0.27750000506639483},
#  {'fighter': 'Branden Lee Hinkle', 'score': 0.27750000506639483},
#  {'fighter': 'Tom Murphy', 'score': 0.27750000506639483},
#  {'fighter': 'Alex Karalexis', 'score': 0.27750000506639483},
#  {'fighter': 'Jonathan Wiezorek', 'score': 0.27750000506639483},
#  {'fighter': 'Keith Rockel', 'score': 0.27750000506639483},
#  {'fighter': 'Dave Strasser', 'score': 0.27750000506639483},
#  {'fighter': 'Benji Radach', 'score': 0.27750000506639483},
#  {'fighter': 'Lance Gibson', 'score': 0.27750000506639483},
#  {'fighter': 'John Lewis', 'score': 0.27750000506639483},
#  {'fighter': 'Mark Hughes', 'score': 0.27750000506639483},
#  {'fighter': 'Tyrone Roberts', 'score': 0.27750000506639483},
#  {'fighter': 'Parker Porter', 'score': 0.27750000506639483},
#  {'fighter': 'Spike Carlyle', 'score': 0.27750000506639483},
#  {'fighter': 'Kyle Daukaus', 'score': 0.27750000506639483},
#  {'fighter': 'Sasha Palatnikov', 'score': 0.27750000506639483},
#  {'fighter': 'Adrian Yanez', 'score': 0.27750000506639483},
#  {'fighter': 'Phillip Hawes', 'score': 0.27750000506639483},
#  {'fighter': 'Modestas Bukauskas', 'score': 0.27750000506639483},
#  {'fighter': 'Guram Kutateladze', 'score': 0.27750000506639483},
#  {'fighter': 'Josh Stansbury', 'score': 0.27750000506639483},
#  {'fighter': 'Garreth McLellan', 'score': 0.27750000506639483},
#  {'fighter': 'Richard Walsh', 'score': 0.27750000506639483},
#  {'fighter': 'John Gunther', 'score': 0.27750000506639483},
#  {'fighter': 'Alvaro Herrera', 'score': 0.27750000506639483},
#  {'fighter': 'Bubba McDaniel', 'score': 0.27750000506639483},
#  {'fighter': 'Marcos Vinicius', 'score': 0.27750000506639483},
#  {'fighter': 'Benny Alloway', 'score': 0.27750000506639483},
#  {'fighter': 'Saparbeg Safarov', 'score': 0.27750000506639483},
#  {'fighter': 'Felipe Colares', 'score': 0.27750000506639483},
#  {'fighter': 'Daniel Teymur', 'score': 0.27750000506639483},
#  {'fighter': 'Matt Arroyo', 'score': 0.27750000506639483},
#  {'fighter': 'Jon Koppenhaver', 'score': 0.27750000506639483},
#  {'fighter': 'Roman Mitichyan', 'score': 0.27750000506639483},
#  {'fighter': 'Logan Clark', 'score': 0.27750000506639483},
#  {'fighter': 'Rob MacDonald', 'score': 0.27750000506639483},
#  {'fighter': 'James McSweeney', 'score': 0.27750000506639483},
#  {'fighter': 'Jesse Lennox', 'score': 0.27750000506639483},
#  {'fighter': 'Jason Dent', 'score': 0.27750000506639483},
#  {'fighter': 'Rolando Delgado', 'score': 0.27750000506639483},
#  {'fighter': 'Mike Ciesnolevicz', 'score': 0.27750000506639483},
#  {'fighter': 'Troy Mandaloniz', 'score': 0.27750000506639483},
#  {'fighter': 'Gabe Green', 'score': 0.27750000506639483},
#  {'fighter': 'Amir Albazi', 'score': 0.27750000506639483},
#  {'fighter': 'Umar Nurmagomedov', 'score': 0.27750000506639483},
#  {'fighter': 'David Zawada', 'score': 0.27750000506639483},
#  {'fighter': 'Tafon Nchukwi', 'score': 0.27750000506639483},
#  {'fighter': 'Jimmy Flick', 'score': 0.27750000506639483},
#  {'fighter': 'Mike Guymon', 'score': 0.2773937501013279},
#  {'fighter': 'Katsunori Kikuno', 'score': 0.2771448143170346},
#  {'fighter': 'Leandro Issa', 'score': 0.27713384209964714},
#  {'fighter': 'Jose Torres', 'score': 0.27692822302924464},
#  {'fighter': 'Scott Askham', 'score': 0.2769192864981961},
#  {'fighter': 'Alex Nicholson', 'score': 0.2759194355612636},
#  {'fighter': 'James Moontasri', 'score': 0.2758302987787261},
#  {'fighter': 'Benito Lopez', 'score': 0.2757200989935882},
#  {'fighter': 'Jordan Leavitt', 'score': 0.2754079781290786},
#  {'fighter': 'Liu Pingyuan', 'score': 0.2749247270614433},
#  {'fighter': 'Mike Kyle', 'score': 0.27472864717074114},
#  {'fighter': 'Deron Winn', 'score': 0.2745819360381574},
#  {'fighter': 'Oskar Piechota', 'score': 0.2741415590389352},
#  {'fighter': 'Jutaro Nakao', 'score': 0.2740858641869636},
#  ...]

# %%
#male pagerank
tx = graph.begin()
cypher = '''
CALL gds.pageRank.stream('male_fights')
YIELD
  nodeId,
  score
RETURN gds.util.asNode(nodeId).name AS fighter, score
ORDER BY score DESC
'''
male_pr = pd.DataFrame(tx.run(cypher).data())
male_pr.head(10).to_clipboard(index = False, header = False)
male_pr.head(10)
# Out:
#               fighter      score
# 0        Stipe Miocic  11.215404
# 1        Henry Cejudo  11.042557
# 2  Demetrious Johnson  10.533454
# 3      Dustin Poirier   8.787614
# 4   Junior Dos Santos   8.564045
# 5           Jon Jones   8.470970
# 6     Francis Ngannou   8.453018
# 7    Joseph Benavidez   8.229674
# 8        Max Holloway   8.060076
# 9      Donald Cerrone   7.849873

# %%
#female pagerank
tx = graph.begin()
cypher = '''
CALL gds.pageRank.stream('female_fights')
YIELD
  nodeId,
  score
RETURN gds.util.asNode(nodeId).name AS fighter, score
ORDER BY score DESC
'''
female_pr = pd.DataFrame(tx.run(cypher).data())
female_pr.head(10).to_clipboard(index = False, header = False)
female_pr.head(10)
# Out:
#                 fighter      score
# 0          Amanda Nunes  11.747856
# 1           Cat Zingano  10.529791
# 2            Holly Holm   4.263861
# 3  Valentina Shevchenko   4.202499
# 4  Germaine de Randamie   3.473330
# 5          Ronda Rousey   3.436543
# 6         Carla Esparza   3.342000
# 7         Julianna Pena   3.114530
# 8         Ketlen Vieira   2.848350
# 9          Irene Aldana   2.841481
